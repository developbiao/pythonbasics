# %% [markdown]
# ### Logistic Regression predists chip quality
# 1. 基于 chip_test.csv 数据，建立逻辑回归模型（二阶边界），评估模型表现。
# 2. 以函数的试求解边界曲线。
# 3. 描绘出完整的决策边界曲线。

# %%
# 1. Load data 
import pandas as pd
import numpy as np
data = pd.read_csv('chip_test.csv')
data.head()
# Out:
#       test1    test2  pass
# 0  0.051267  0.69956     1
# 1 -0.092742  0.68494     1
# 2 -0.213710  0.69225     1
# 3 -0.375000  0.50219     1
# 4  0.183760  0.93348     0

# %%
# 2. Visualize data
mask = data.loc[:, 'pass'] == 1
print(~mask)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 113     True
# 114     True
# 115     True
# 116     True
# 117     True
# Name: pass, Length: 118, dtype: bool

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
fig1 = plt.figure()
passed = plt.scatter(data.loc[:, 'test1'][mask], data.loc[:, 'test2'][mask])
failed = plt.scatter(data.loc[:, 'test1'][~mask], data.loc[:, 'test2'][~mask])
plt.title('test1-test2')
plt.xlabel('test1')
plt.xlabel('test2')
plt.legend((passed, failed), ('passd', 'failed'))
plt.show()

# %%
# 3. Generate new data
# define X, y
X = data.drop(['pass'], axis = 1)
y = data.loc[:, 'pass']
X1 = data.loc[:, 'test1']
X2 = data.loc[:, 'test2']
X1.head()
# Out:
# 0    0.69956
# 1    0.68494
# 2    0.69225
# 3    0.50219
# 4    0.93348
# Name: test2, dtype: float64

# %%
# Create new data 
X1_2 = X1 * X1
X2_2 = X2 * X2
X1_X2 = X1 * X2
X_new = {'X1': X1, 'X2': X2, 'X1_2': X1_2, 'X2_2': X2_2, 'X1_X2': X1_X2}
X_new = pd.DataFrame(X_new)
print(X_new)
# Out:
#            X1        X2      X1_2      X2_2     X1_X2
# 0    0.051267  0.699560  0.002628  0.489384  0.035864
# 1   -0.092742  0.684940  0.008601  0.469143 -0.063523
# 2   -0.213710  0.692250  0.045672  0.479210 -0.147941
# 3   -0.375000  0.502190  0.140625  0.252195 -0.188321
# 4    0.183760  0.933480  0.033768  0.871385  0.171536
# ..        ...       ...       ...       ...       ...
# 113 -0.720620  0.538740  0.519293  0.290241 -0.388227
# 114 -0.593890  0.494880  0.352705  0.244906 -0.293904
# 115 -0.484450  0.999270  0.234692  0.998541 -0.484096
# 116 -0.006336  0.999270  0.000040  0.998541 -0.006332
# 117  0.632650 -0.030612  0.400246  0.000937 -0.019367
#
# [118 rows x 5 columns]

# %%
# 4. Establish new model and train
# Establish the model and train it
from sklearn.linear_model import LogisticRegression
LR2 = LogisticRegression()
LR2.fit(X_new, y)
# Out:
# LogisticRegression()

# %%
# Accuracy validation
from sklearn.metrics import accuracy_score
y2_predict = LR2.predict(X_new)
accuracy2 = accuracy_score(y, y2_predict)
print(accuracy2)
# Out:
# 0.8135593220338984

# %%
# Visiualize Accuracy
X1_new = X1.sort_values()
theta0 = LR2.intercept_
theta1, theta2, theta3, theta4, theta5 = LR2.coef_[0][0],LR2.coef_[0][1],LR2.coef_[0][2],LR2.coef_[0][3],LR2.coef_[0][4]
a = theta4
b = theta5 * X1_new + theta2
c = theta0 + theta1 * X1_new + theta3 * X1_new * X1_new
X2_new_boundary = (-b + np.sqrt(b * b - 4 * a * c)) / (2 * a)

fig2 = plt.figure()
passed = plt.scatter(data.loc[:, 'test1'][mask], data.loc[:, 'test2'][mask])
failed = plt.scatter(data.loc[:, 'test1'][~mask], data.loc[:, 'test2'][~mask])
plt.plot(X1_new, X2_new_boundary)
plt.title('test1-test2')
plt.xlabel('test1')
plt.xlabel('test2')
plt.legend((passed, failed), ('passd', 'failed'))
plt.show()

# %%
d = np.array(b * b - 4 * a * c)
print(X1_new)
# Out:
# 112   -0.83007
# 86    -0.75518
# 84    -0.74366
# 111   -0.72638
# 113   -0.72062
#         ...
# 70     0.89804
# 65     0.92684
# 68     0.93836
# 67     0.96141
# 101    1.07090
# Name: test1, Length: 118, dtype: float64

# %%
# Define boundary function
def boundary(x):
    a = theta4
    b = theta5 * x  + theta2
    c = theta0 + theta1 * x + theta3 * x * x
    X2_new_boundary1 = (-b + np.sqrt(b * b -4 * a * c)) / (2 * a)
    X2_new_boundary2 = (-b - np.sqrt(b * b -4 * a * c)) / (2 * a)
    return X2_new_boundary1, X2_new_boundary2

# %%
X2_new_boundary1 = []
X2_new_boundary2 = []
for x in X1_new:
    result = boundary(x)
    X2_new_boundary1.append(result[0])
    X2_new_boundary2.append(result[1])
print(X2_new_boundary1, X2_new_boundary2)
# Out:
# [array([nan]), array([nan]), array([nan]), array([nan]), array([nan]), array([nan]), array([nan]), array([nan]), array([0.1212617]), array([0.04679448]), array([0.02697935]), array([0.00872189]), array([-0.00830576]), array([-0.00830576]), array([-0.11718731]), array([-0.16040224]), array([-0.18016521]), array([-0.18965258]), array([-0.21671004]), array([-0.22530078]), array([-0.23369452]), array([-0.2499261]), array([-0.28761583]), array([-0.30846849]), array([-0.32171919]), array([-0.32816104]), array([-0.33448523]), array([-0.34069505]), array([-0.35278365]), array([-0.35866807]), array([-0.37013014]), array([-0.42186137]), array([-0.42656594]), array([-0.43119936]), array([-0.43574686]), array([-0.44021779]), array([-0.45318277]), array([-0.47336128]), array([-0.47336128]), array([-0.48465118]), array([-0.48828317]), array([-0.49185073]), array([-0.49185073]), array([-0.51193977]), array([-0.51193977]), array([-0.5181489]), array([-0.52412149]), array([-0.52986615]), array([-0.52
# ...

# %%
fig3 = plt.figure()
passed = plt.scatter(data.loc[:, 'test1'][mask], data.loc[:, 'test2'][mask])
failed = plt.scatter(data.loc[:, 'test1'][~mask], data.loc[:, 'test2'][~mask])
plt.plot(X1_new, X2_new_boundary1)
plt.plot(X1_new, X2_new_boundary2)
plt.title('test1-test2')
plt.xlabel('test1')
plt.xlabel('test2')
plt.legend((passed, failed), ('passd', 'failed'))
plt.show()

# %%
# Supplement data
X1_range = [-0.8 + x / 10000 for x in range (0, 18000)]
X1_range = np.array(X1_range)
X2_new_boundary1 = []
X2_new_boundary2 = []
for x in X1_range:
    result = boundary(x)
    X2_new_boundary1.append(result[0])
    X2_new_boundary2.append(result[1])
# Out:
# /var/folders/ql/y3m1vwns27qdfzv3sd7yc9hr0000gn/T/ipykernel_46657/3071677893.py:6: RuntimeWarning: invalid value encountered in sqrt
#   X2_new_boundary1 = (-b + np.sqrt(b * b -4 * a * c)) / (2 * a)
# /var/folders/ql/y3m1vwns27qdfzv3sd7yc9hr0000gn/T/ipykernel_46657/3071677893.py:7: RuntimeWarning: invalid value encountered in sqrt
#   X2_new_boundary2 = (-b - np.sqrt(b * b -4 * a * c)) / (2 * a)

# %%
# Visualize new chart
# coding:utf-8
import matplotlib as mlp
mlp.rcParams['font.family'] = 'Calibri'
mlp.rcParams['axes.unicode_minus'] = False
fig4 = plt.figure()
passed = plt.scatter(data.loc[:, 'test1'][mask], data.loc[:, 'test2'][mask])
failed = plt.scatter(data.loc[:, 'test1'][~mask], data.loc[:, 'test2'][~mask])
plt.plot(X1_range, X2_new_boundary1, 'r')
plt.plot(X1_range, X2_new_boundary2, 'r')
plt.title('Chip Quality Predicts')
plt.xlabel('test1')
plt.xlabel('test2')
plt.legend((passed, failed), ('passd', 'failed'))
plt.show()
# Out:
# findfont: Font family 'Calibri' not found.
# findfont: Font family 'Calibri' not found.
# findfont: Font family 'Calibri' not found.
# findfont: Font family 'Calibri' not found.
# findfont: Font family 'Calibri' not found.
# findfont: Font family 'Calibri' not found.
# findfont: Font family 'Calibri' not found.
# findfont: Font family 'Calibri' not found.
# findfont: Font family 'Calibri' not found.
# findfont: Font family 'Calibri' not found.
# findfont: Font family 'Calibri' not found.
# findfont: Font family 'Calibri' not found.
# findfont: Font family 'Calibri' not found.
# findfont: Font family 'Calibri' not found.
# findfont: Font family 'Calibri' not found.
# findfont: Font family 'Calibri' not found.
# findfont: Font family 'Calibri' not found.
# findfont: Font family 'Calibri' not found.
# findfont: Font family 'Calibri' not found.
# findfont: Font family 'Calibri' not found.
# findfont: Font family 'Calibri' not found.
# findfont: Font family 'Calibri' not found.
# ...
